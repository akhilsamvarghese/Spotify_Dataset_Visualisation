# %% [markdown]
# # **Spotify Dataset Visualisation**

# %% [markdown]
# *****

# %% [markdown]
# ### **Importing Necessary Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Importing the Dataset**

# %%
df = pd.read_csv("/Users/akhilsamvarghese/Desktop/Projects/CQAI/Data-Visualization/Spotify_Visualization/spotify-2023.csv", encoding="latin-1")
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %% [markdown]
# ### **Exploring the Dataset**

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %% [markdown]
# # **Pre-processing the Dataset**
# *****

# %% [markdown]
# ### **Check for missing values**

# %%
print(df.isnull().sum())
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
# Dropping the missing values
df = df.dropna()

# %%
#Checking if the missing values are dropped
print(df.isnull().sum())
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# in_shazam_charts        0
# bpm                     0
# key                     0
# mode                    0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64

# %%
# Check for duplicates
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # **Convert data types:**

# %%
# Convert 'streams' column to integer type
# Remove rows where 'streams' column contains non-numeric values
df = df[pd.to_numeric(df['streams'], errors='coerce').notnull()]

# Convert 'streams' column to integer type
df['streams'] = df['streams'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            816 non-null    object
#  1   artist(s)_name        816 non-null    object
#  2   artist_count          816 non-null    int64
#  3   released_year         816 non-null    int64
#  4   released_month        816 non-null    int64
#  5   released_day          816 non-null    int64
#  6   in_spotify_playlists  816 non-null    int64
#  7   in_spotify_charts     816 non-null    int64
#  8   streams               816 non-null    int64
#  9   in_apple_playlists    816 non-null    int64
#  10  in_apple_charts       816 non-null    int64
#  11  in_deezer_playlists   816 non-null    object
#  12  in_deezer_charts      816 non-null    int64
#  13  in_shazam_charts      816 non-null    object
#  14  bpm                   816 non-null    int64
# ...

# %%
# Renaming the columns 
df = df.rename(columns={
    'artist(s)_name': 'artists',
    'released_year': 'year',
    'released_month': 'month',
    'released_day': 'day'
})

# %%
df.head()
# Out:
#                             track_name           artists  artist_count  year  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2  2023
# 1                                 LALA       Myke Towers             1  2023
# 2                              vampire    Olivia Rodrigo             1  2023
# 3                         Cruel Summer      Taylor Swift             1  2019
# 4                       WHERE SHE GOES         Bad Bunny             1  2023
#
#    month  day  in_spotify_playlists  in_spotify_charts    streams  \
# 0      7   14                   553                147  141381703
# 1      3   23                  1474                 48  133716286
# 2      6   30                  1397                113  140003974
# 3      8   23                  7858                100  800840817
# 4      5   18                  3133                 50  303236322
#
#    in_apple_playlists  ...  bpm key   mode danceability_%  valence_% energy_%  \
# ...

# %%
# Create release_date column
df['release_date'] = pd.to_datetime(df[['year', 'month', 'day']])

# %%
# Remove unnecessary columns
columns_to_drop = ['year', 'month', 'day']  # Add any other columns you don't need
df = df.drop(columns=columns_to_drop)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 952
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            816 non-null    object
#  1   artists               816 non-null    object
#  2   artist_count          816 non-null    int64
#  3   in_spotify_playlists  816 non-null    int64
#  4   in_spotify_charts     816 non-null    int64
#  5   streams               816 non-null    int64
#  6   in_apple_playlists    816 non-null    int64
#  7   in_apple_charts       816 non-null    int64
#  8   in_deezer_playlists   816 non-null    object
#  9   in_deezer_charts      816 non-null    int64
#  10  in_shazam_charts      816 non-null    object
#  11  bpm                   816 non-null    int64
#  12  key                   816 non-null    object
#  13  mode                  816 non-null    object
#  14  danceability_%        816 non-null    int64
# ...

# %% [markdown]
# ### **Outlier Detection and Handling**

# %%
# Plot boxplots for numerical columns to identify outliers
numerical_columns = df.select_dtypes(include=[np.number]).columns
fig, axes = plt.subplots(nrows=len(numerical_columns), figsize=(10, 5*len(numerical_columns)))
for i, col in enumerate(numerical_columns):
    sns.boxplot(x=df[col], ax=axes[i])
    axes[i].set_title(col)
plt.tight_layout()
plt.show()

# %%
# After identifying outliers, the next steps are to analyze their impact and decide how to handle them.
# We'll use the Interquartile Range (IQR) method to detect outliers and then create a function to handle them.

def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] < lower_bound) | (df[column] > upper_bound)]

def handle_outliers(df, column, method='clip'):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    if method == 'clip':
        return df[column].clip(lower_bound, upper_bound)
    elif method == 'remove':
        return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    else:
        raise ValueError("Method must be either 'clip' or 'remove'")

# Analyze outliers for each numerical column
for column in numerical_columns:
    outliers = detect_outliers(df, column)
    print(f"Outliers in {column}: {len(outliers)} ({len(outliers)/len(df)*100:.2f}%)")
    
    # Handle outliers (here we're using the 'clip' method, but you can change it to 'remove' if needed)
    df[column] = handle_outliers(df, column, method='clip')

# Verify that outliers have been handled
fig, axes = plt.subplots(nrows=len(numerical_columns), figsize=(10, 5*len(numerical_columns)))
for i, col in enumerate(numerical_columns):
    sns.boxplot(x=df[col], ax=axes[i])
    axes[i].set_title(f"{col} (after handling outliers)")
plt.tight_layout()
plt.show()

# Print summary statistics after handling outliers
print(df[numerical_columns].describe())
# Out:
# Outliers in artist_count: 24 (2.94%)
# Outliers in in_spotify_playlists: 90 (11.03%)
# Outliers in in_spotify_charts: 66 (8.09%)
# Outliers in streams: 67 (8.21%)
# Outliers in in_apple_playlists: 67 (8.21%)
# Outliers in in_apple_charts: 11 (1.35%)
# Outliers in in_deezer_charts: 116 (14.22%)
# Outliers in bpm: 1 (0.12%)
# Outliers in danceability_%: 1 (0.12%)
# Outliers in valence_%: 0 (0.00%)
# Outliers in energy_%: 2 (0.25%)
# Outliers in acousticness_%: 1 (0.12%)
# Outliers in instrumentalness_%: 75 (9.19%)
# Outliers in liveness_%: 36 (4.41%)
# Outliers in speechiness_%: 102 (12.50%)
#        artist_count  in_spotify_playlists  in_spotify_charts       streams  \
# count    816.000000             816.00000         816.000000  8.160000e+02
# mean       1.531863            3479.46538          10.117647  4.227759e+08
# std        0.737407            3511.27840          13.628584  3.889439e+08
# min        1.000000              31.00000           0.000000  2.762000e+03
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 952
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            816 non-null    object
#  1   artists               816 non-null    object
#  2   artist_count          816 non-null    float64
#  3   in_spotify_playlists  816 non-null    float64
#  4   in_spotify_charts     816 non-null    int64
#  5   streams               816 non-null    float64
#  6   in_apple_playlists    816 non-null    float64
#  7   in_apple_charts       816 non-null    int64
#  8   in_deezer_playlists   816 non-null    object
#  9   in_deezer_charts      816 non-null    int64
#  10  in_shazam_charts      816 non-null    object
#  11  bpm                   816 non-null    float64
#  12  key                   816 non-null    object
#  13  mode                  816 non-null    object
#  14  danceability_%        816 non-null    int64
# ...

# %%
# Convert float64 columns to int
float_columns = df.select_dtypes(include=['float64']).columns
for col in float_columns:
    df[col] = df[col].astype(int)

# Verify the changes
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 952
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            816 non-null    object
#  1   artists               816 non-null    object
#  2   artist_count          816 non-null    int64
#  3   in_spotify_playlists  816 non-null    int64
#  4   in_spotify_charts     816 non-null    int64
#  5   streams               816 non-null    int64
#  6   in_apple_playlists    816 non-null    int64
#  7   in_apple_charts       816 non-null    int64
#  8   in_deezer_playlists   816 non-null    object
#  9   in_deezer_charts      816 non-null    int64
#  10  in_shazam_charts      816 non-null    object
#  11  bpm                   816 non-null    int64
#  12  key                   816 non-null    object
#  13  mode                  816 non-null    object
#  14  danceability_%        816 non-null    int64
# ...

# %% [markdown]
# ### **Exporting the cleaned data-frame into a csv file**

# %%
df.to_csv("cleaned_spotify_data.csv", index=False)

# %% [markdown]
# ## **Data Visualization**
# *****

# %%
### **Univariate Analysis**

# **1. Analyzing the distribution of 'streams'**
plt.figure(figsize=(10, 6))
sns.histplot(df['streams'], bins=50, kde=True)
plt.title('Distribution of Streams')
plt.xlabel('Streams')
plt.ylabel('Frequency')
plt.show()
